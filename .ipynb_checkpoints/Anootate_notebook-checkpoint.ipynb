# %%
import glob

def box_annotation(gun_directory):
    read_dir = glob.glob(gun_directory)
    for read_file in read_dir:
        rename_file = read_file.replace(
            '/home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/',
            '')
        flag = 0
        count = 0
        with open(read_file) as file:
            lines = file.readlines()
            lines = [line.rstrip() for line in lines]
            for i in lines:
                #print(i, "----------",read_file)

#                 li_file = list()
#                 if i.find("15") == 0:
#                     li_file.append("0" + i[2:])
#                 else:
#                     li_file.append("0" + i[2:])

#                 print(li_file)
#                 with open(
#                         "/home/cygnet/Documents/Gaurav/Sacks/sack_counting_data_v3/labels/validation_v2/" + rename_file,
#                         'a') as fd:
#                     if flag == 0:
#                         fd.write(f'{li_file[0]}')
#                         flag = 1
#                     else:
#                         fd.write(f'\n{li_file[0]}')
#                 count += 1
#         print(count)

gun_directory = '/home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/*'

box_annotation(gun_directory)
# Out:
# 16 0.497143 0.405894 0.522857 0.785171 ---------- /home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/sleeping_v2_8.txt
# 16 0.481667 0.568452 0.256667 0.553571 ---------- /home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/sleeping_v2_72.txt
# 16 0.571906 0.449405 0.240803 0.601190 ---------- /home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/sleeping_v2_44.txt
# 15 0.484076 0.520701 0.251592 0.353503 ---------- /home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/sleeping_person_3.txt
# 15 0.337903 0.424286 0.214516 0.305714 ---------- /home/cygnet/Documents/Gaurav/DATASET/Models/suspicious_dataset/sleeping_videos/sleeping_v1/labels/sleeping_person_236.txt
# ...
